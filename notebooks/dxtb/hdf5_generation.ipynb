# %%
# %reload_ext autoreload
# %autoreload 2

import h5py
from tqdm import tqdm

from qcm_ml.features.xtb import generate_xtb_matrices_fpsh

src_path = "/home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/data/qm9/QM9_open_gen_10000.hdf5"
tgt_path = "/home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/data/qm9/QM9_open_gen_10000_DXTB_test.hdf5"



with h5py.File(src_path, 'r') as src_file:
    with h5py.File(tgt_path, 'w') as tgt_file:
        for mode in src_file:
            for mol in tqdm(src_file[mode], desc=mode + " molecules"):
                singlet_group = src_file[mode][mol].get("singlet", None)
                if singlet_group is not None:
                    tgt_singlet_group = tgt_file.create_group(f"{mode}/{mol}/singlet")
                    for key, item in singlet_group.items():
                        if key in ["2body"]:
                            continue
                        else: 
                            if item.shape == ():
                                tgt_singlet_group.create_dataset(key, data=item[()])
                            else:
                                tgt_singlet_group.create_dataset(key, data=item[:])

                    # Calculation of 2body features
                    numbers = singlet_group["atomic_numbers"][:] # Repetitive but looks better
                    positions = singlet_group["geometry_bohr"][:]
                    T = generate_xtb_matrices_fpsh(
                        calculator="dxtb",
                        # calculator="tblite",
                        element_numbers=numbers,
                        coordinates=positions,
                        spin=0,
                        spin_pol=True,
                        # spin_pol=False
                        )
                    for M in ["F_a", "F_b", "H", "P_a", "P_b", "S"]:
                    # for M in ["F", "H", "P", "S"]:
                        tgt_singlet_group.create_dataset(f"2body/{M}", data=T[M])
# Out:
# train molecules:   0%|          | 0/10000 [00:00<?, ?it/s]
# train molecules:   4%|▍         | 394/10000 [00:34<13:57, 11.47it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 33
#      31 numbers = singlet_group["atomic_numbers"][:] # Repetitive but looks better
#      32 positions = singlet_group["geometry_bohr"][:]
# ---> 33 T = generate_xtb_matrices_fpsh(
#      34     calculator="dxtb",
#      35     # calculator="tblite",
#      36     element_numbers=numbers,
#      37     coordinates=positions,
#      38     spin=0,
#      39     spin_pol=True,
#      40     # spin_pol=False
#      41     )
#      42 for M in ["F_a", "F_b", "H", "P_a", "P_b", "S"]:
#      43 # for M in ["F", "H", "P", "S"]:
#      44     tgt_singlet_group.create_dataset(f"2body/{M}", data=T[M])
#
# File ~/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:136, in generate_xtb_matrices_fpsh(calculator, element_numbers, spin_pol, cutoff, *args, **kwargs)
#     131     res_dict = generate_xtb_matrices_tblite(*args,
#     132                                             element_numbers=element_numbers,
#     133                                             spin_pol=spin_pol,
#     134                                             **kwargs)
#     135 elif calculator == "dxtb":
# --> 136     res_dict = generate_xtb_matrices_dxtb(*args,
#     137                                           element_numbers=element_numbers,
#     138                                           spin_pol=spin_pol,
#     139                                           **kwargs)
#     141 # Correcting orbital order for OrbNet-Equi's convention
#     142 perm_map = _get_permutation_map_closedshell_convention(element_numbers, calculator)
#
# File ~/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:237, in generate_xtb_matrices_dxtb(element_numbers, coordinates, option, charge, spin, spin_pol, get_energy, get_forces, verbosity)
#     235 S = overlap(numbers, pos, par).to("cpu")
#     236 H = hcore(numbers, pos, par).to("cpu")
# --> 237 P = calc.get_density(pos, chrg=charge, spin=spin).to("cpu")
#     238 E = calc.get_mo_energies(pos, chrg=charge, spin=spin).to("cpu")
#     239 C = calc.get_coefficients(pos, chrg=charge, spin=spin).to("cpu")
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/abc.py:422, in GetPropertiesMixin.get_density(self, positions, chrg, spin, **kwargs)
#     415 def get_density(
#     416     self,
#     417     positions: Tensor,
#    (...)
#     420     **kwargs: Any,
#     421 ) -> Tensor:
# --> 422     prop = self.get_property(
#     423         "density", positions, chrg=chrg, spin=spin, **kwargs
#     424     )
#     425     assert isinstance(prop, Tensor)
#     426     return prop
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/base.py:769, in BaseCalculator.get_property(self, name, positions, chrg, spin, allow_calculation, return_clone, **kwargs)
#     762         raise DeviceError(
#     763             f"Device mismatch: Calculator is on '{self.device}', but "
#     764             f"spin is on '{spin.device}'."
#     765         )
#     767 # All the cache checks are handled deep within `calculate`. No need to
#     768 # do it here as well.
# --> 769 self.calculate([name], positions, chrg=chrg, spin=spin, **kwargs)
#     771 # For some reason the calculator was not able to do what we want...
#     772 if name not in self.cache:
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/base.py:59, in Calculator.calculate(self, properties, positions, chrg, spin, **kwargs)
#      51 def calculate(
#      52     self,
#      53     properties: list[str],
#    (...)
#      57     **kwargs: Any,
#      58 ):
# ---> 59     AutogradCalculator.calculate(
#      60         self, properties, positions, chrg, spin, **kwargs
#      61     )
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/autograd.py:1042, in AutogradCalculator.calculate(self, properties, positions, chrg, spin, **kwargs)
#    1039 props.remove("bond_orders")
#    1041 if set(props) & set(properties):
# -> 1042     self.energy(positions, chrg, spin, **kwargs)
#    1044 if "forces" in properties:
#    1045     self.forces(positions, chrg, spin, **kwargs)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/decorators.py:259, in cache.<locals>.wrapper(self, *args, **kwargs)
#     256                 return self.cache[key]
#     258 # Execute the function and store the result in the cache
# --> 259 result = func(self, *args, **kwargs)
#     260 self.cache[key] = result
#     262 # Also store the "hashkey"
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/energy.py:386, in EnergyCalculator.energy(self, positions, chrg, spin, **kwargs)
#     361 @cdec.cache
#     362 def energy(
#     363     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> Tensor:
#     369     """
#     370     Calculate the total energy :math:`E` of the system.
#     371
#    (...)
#     384         Total energy of the system (scalar value).
#     385     """
# --> 386     self.singlepoint(positions, chrg, spin, **kwargs)
#     387     e = self.cache["energy"]
#     389     if e is None:
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/energy.py:250, in EnergyCalculator.singlepoint(self, positions, chrg, spin, **kwargs)
#     247 # SCF
#     248 OutputHandler.write_stdout("\nStarting SCF Iterations...", v=3)
# --> 250 scf_results = scf.solve(
#     251     self.numbers,
#     252     positions,
#     253     chrg,
#     254     spin,
#     255     self.interactions,
#     256     icaches,
#     257     self.ihelp,
#     258     self.opts.scf,
#     259     intmats,
#     260     self.integrals.hcore.refocc,
#     261 )
#     263 timer.stop("SCF")
#     264 timer.cuda_sync = old_cuda_sync
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/iterator.py:133, in solve(numbers, positions, chrg, spin, interactions, cache, ihelp, config, integrals, refocc, *args, **kwargs)
#     130 else:
#     131     raise ValueError(f"Unknown SCF mode '{config.scf_mode}'.")
# --> 133 return SCF(
#     134     interactions,
#     135     occupation,
#     136     n0,
#     137     *args,
#     138     numbers=numbers,
#     139     ihelp=ihelp,
#     140     cache=cache,
#     141     integrals=integrals,
#     142     config=config,
#     143     **kwargs,
#     144 )(charges)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:440, in BaseSCF.__call__(self, charges)
#     433 OutputHandler.write_stdout(
#     434     f"\n{'iter':<5} {'Energy':<24} {'Delta E':<16}"
#     435     f"{'Delta Pnorm':<15} {'Delta q':<15}",
#     436     v=3,
#     437 )
#     438 OutputHandler.write_stdout(77 * "-", v=3)
# --> 440 q = self.scf(guess)
#     442 OutputHandler.write_stdout(77 * "-", v=3)
#     443 OutputHandler.write_stdout("", v=3)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/implicit/default.py:63, in SelfConsistentFieldImplicit.scf(self, guess, return_charges)
#      59 fcn = self._fcn
#      61 # TODO: Pass mixer options in `method` arg.
#      62 # Currently ignored. Always "broyden1".
# ---> 63 q_converged = xt.optimize.equilibrium(
#      64     fcn=fcn,
#      65     y0=guess,
#      66     bck_options={**self.bck_options},
#      67     **self.fwd_options,
#      68 )
#      70 # To reconnect the H0 energy with the computational graph, we
#      71 # compute one extra SCF cycle with strong damping.
#      72 # Note that this is not required for SCF with full gradient tracking.
#      73 # (see https://github.com/grimme-lab/dxtb/issues/124)
#      74 if self.config.scp_mode == labels.SCP_MODE_CHARGE:
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:222, in equilibrium(fcn, y0, params, bck_options, method, **fwd_options)
#     219     return y - pfunc(y, *params)
#     221 fwd_options["method"] = _get_rootfinder_default_method(method)
# --> 222 return _rootfinder(
#     223     new_fcn,
#     224     y0,
#     225     new_fcn,
#     226     False,
#     227     fwd_options,
#     228     bck_options,
#     229     len(params),
#     230     *params,
#     231     *pfunc.objparams(),
#     232 )
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:355, in _rootfinder(fcn, y0, fwd_fcn, is_opt_method, options, bck_options, nparams, *allparams)
#     351 def _rootfinder(
#     352     fcn, y0, fwd_fcn, is_opt_method, options, bck_options, nparams, *allparams
#     353 ) -> Tensor:
#     354     _RootFinder = RootFinder_V1 if __tversion__ < (2, 0, 0) else RootFinder_V2
# --> 355     r = _RootFinder.apply(
#     356         fcn,
#     357         y0,
#     358         fwd_fcn,
#     359         is_opt_method,
#     360         options,
#     361         bck_options,
#     362         nparams,
#     363         *allparams,
#     364     )
#     365     assert r is not None
#     366     return r
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/function.py:506, in Function.apply(cls, *args, **kwargs)
#     503 if not torch._C._are_functorch_transforms_active():
#     504     # See NOTE: [functorch vjp and autograd interaction]
#     505     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 506     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     508 if cls.setup_context == _SingleLevelFunction.setup_context:
#     509     raise RuntimeError(
#     510         'In order to use an autograd.Function with functorch transforms '
#     511         '(vmap, grad, jvp, jacrev, ...), it must override the setup_context '
#     512         'staticmethod. For more details, please see '
#     513         'https://pytorch.org/docs/master/notes/extending.func.html')
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:512, in RootFinder_V2.forward(fcn, y0, fwd_fcn, is_opt_method, options, bck_options, nparams, *allparams)
#     510     name = "rootfinder" if not is_opt_method else "minimizer"
#     511     method_fcn = get_method(name, methods, method)
# --> 512     y = method_fcn(fwd_fcn, y0, params, **config)
#     514 return y
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:245, in broyden1(fcn, x0, params, **kwargs)
#     229 @functools.wraps(
#     230     _nonlin_solver, assigned=("__annotations__",)
#     231 )  # takes only the signature
#     232 def broyden1(fcn, x0, params=(), **kwargs):
#     233     """
#     234     Solve the root finder or linear equation using the first Broyden method [1]_.
#     235     It can be used to solve minimization by finding the root of the
#    (...)
#     243            https://web.archive.org/web/20161022015821/http://www.math.leidenuniv.nl/scripties/Rotten.pdf
#     244     """
# --> 245     return _nonlin_solver(fcn, x0, params, "broyden1", **kwargs)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:172, in _nonlin_solver(fcn, x0, params, method, alpha, uv0, max_rank, maxiter, f_tol, f_rtol, x_tol, x_rtol, line_search, verbose, **unused)
#     170 s = 0.95  # modified!!
#     171 xnew = x + s * dx
# --> 172 ynew = func(xnew)
#     173 y_norm_new = torch.norm(ynew)
#     174 assert isinstance(y_norm_new, torch.Tensor)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:128, in _nonlin_solver.<locals>.<lambda>(x)
#     126 # shorthand for the function
#     127 xshape = x0.shape
# --> 128 func = lambda x: _ravel(fcn(_pack(x), *params))
#     129 x = _ravel(x0)
#     131 y = func(x)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/pure_function.py:56, in PureFunction.__call__(self, *params)
#      55 def __call__(self, *params):
# ---> 56     return self._fcntocall(*params)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:219, in equilibrium.<locals>.new_fcn(y, *params)
#     217 @make_sibling(pfunc)
#     218 def new_fcn(y, *params):
# --> 219     return y - pfunc(y, *params)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/pure_function.py:56, in PureFunction.__call__(self, *params)
#      55 def __call__(self, *params):
# ---> 56     return self._fcntocall(*params)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:736, in BaseSCF.iterate_potential(self, potential)
#     720 """
#     721 Perform single self-consistent iteration.
#     722
#    (...)
#     731     New potential vector for each orbital partial charge.
#     732 """
#     733 pot = Potential.from_tensor(
#     734     potential, self._data.potential, batch_mode=self.config.batch_mode
#     735 )
# --> 736 charges = self.potential_to_charges(pot)
#     738 # FIXME: Batch print not working!
#     739 self._print(charges)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:810, in BaseSCF.potential_to_charges(self, potential)
#     796 def potential_to_charges(self, potential: Potential) -> Charges:
#     797     """
#     798     Compute the orbital charges from the potential.
#     799
#    (...)
#     808         Orbital-resolved partial charges vector.
#     809     """
# --> 810     self._data.density = self.potential_to_density(potential)
#     811     return self.density_to_charges(self._data.density)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:829, in BaseSCF.potential_to_density(self, potential)
#     814 """
#     815 Obtain the density matrix from the potential.
#     816
#    (...)
#     825     Density matrix.
#     826 """
#     828 self._data.hamiltonian = self.potential_to_hamiltonian(potential)
# --> 829 return self.hamiltonian_to_density(self._data.hamiltonian)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:959, in BaseSCF.hamiltonian_to_density(self, hamiltonian)
#     955 # Fermi smearing only for non-zero electronic temperature
#     956 if self.kt is not None and not torch.all(
#     957     self.kt < 3e-7
#     958 ):  # 0.1 Kelvin * K2AU
# --> 959     self._data.occupation = filling.get_fermi_occupation(
#     960         nel,
#     961         emo,
#     962         kt=self.kt,
#     963         mask=mask,
#     964         maxiter=self.config.fermi.maxiter,
#     965         thr=self.config.fermi.thresh,
#     966     )
#     968     # check if number of electrons is still correct
#     969     _nel = self._data.occupation.sum(-1)
#
# File ~/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/wavefunction/filling.py:351, in get_fermi_occupation(nel, emo, kt, mask, thr, maxiter)
#     348 # only singly occupied here         v
#     349 fermi = torch.where(exponent < 50, 1.0 / (eterm + 1.0), zero)
#     350 dfermi = torch.where(
# --> 351     exponent < 50, eterm / (kt * (eterm + 1.0) ** 2), eps
#     352 )
#     354 _nel = torch.sum(fermi, dim=-1, keepdim=True)
#     355 change = (homo - _nel + 1) / torch.sum(dfermi, dim=-1, keepdim=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # Profiler

# %%
import h5py
from tqdm import tqdm
import cProfile
import pstats
from qcm_ml.features.xtb import generate_xtb_matrices_fpsh

src_path = "/home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/data/qm9/QM9_open_gen_10000.hdf5"
tgt_path = "/home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/data/qm9/QM9_open_gen_10000_DXTB_test.hdf5"

MAX_IDX = 100

def process_data():
    index = 0
    with h5py.File(src_path, 'r') as src_file:
        with h5py.File(tgt_path, 'w') as tgt_file:
            for mode in src_file:
                for mol in tqdm(src_file[mode], desc=mode + " molecules"):
                    if index >= MAX_IDX:
                        break
                    index += 1
                    singlet_group = src_file[mode][mol].get("singlet", None)
                    if singlet_group is not None:
                        tgt_singlet_group = tgt_file.create_group(f"{mode}/{mol}/singlet")
                        for key, item in singlet_group.items():
                            if key in ["2body"]:
                                continue
                            else: 
                                if item.shape == ():
                                    tgt_singlet_group.create_dataset(key, data=item[()])
                                else:
                                    tgt_singlet_group.create_dataset(key, data=item[:])

                        # Calculation of 2body features
                        numbers = singlet_group["atomic_numbers"][:]  # Repetitive but looks better
                        positions = singlet_group["geometry_bohr"][:]
                        T = generate_xtb_matrices_fpsh(
                            calculator="dxtb",
                            element_numbers=numbers,
                            coordinates=positions,
                            spin=0,
                            spin_pol=True,
                        )
                        for M in ["F_a", "F_b", "H", "P_a", "P_b", "S"]:
                            tgt_singlet_group.create_dataset(f"2body/{M}", data=T[M])

# Profiling the process_data function
if __name__ == '__main__':
    profiler = cProfile.Profile()
    profiler.enable()
    process_data() 
    profiler.disable()
    
    # Print the profiling results sorted by cumulative time
    stats = pstats.Stats(profiler).sort_stats('cumulative')
    stats.print_stats(20)  # Print the top 20 results
# Out:
# train molecules:   1%|          | 100/10000 [00:10<17:59,  9.17it/s]
# val molecules:   0%|          | 0/5092 [00:00<?, ?it/s]
#          3523470 function calls (3502007 primitive calls) in 10.937 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1714 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.091    0.091   10.946   10.946 /tmp/ipykernel_5633/2789303748.py:12(process_data)
#       100    0.103    0.001   10.252    0.103 /home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:96(generate_xtb_matrices_fpsh)
#       100    0.012    0.000   10.126    0.101 /home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:202(generate_xtb_matrices_dxtb)
#       300    0.003    0.000    7.238    0.024 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/base.py:691(get_property)
#       300    0.001    0.000    7.233    0.024 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/base.py:51(calculate)
#       300    0.003    0.000    7.233    0.024 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/autograd.py:1001(calculate)
#       300    0.005    0.000    7.229    0.024 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/decorators.py:228(wrapper)
#       100    0.001    0.000    7.228    0.072 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/abc.py:415(get_density)
#       100    0.004    0.000    7.219    0.072 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/energy.py:361(energy)
#       100    0.022    0.000    7.214    0.072 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/energy.py:78(singlepoint)
#       100    0.003    0.000    5.039    0.050 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/iterator.py:51(solve)
#       100    0.003    0.000    4.585    0.046 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:413(__call__)
#       100    0.002    0.000    4.269    0.043 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/implicit/default.py:53(scf)
#  1488/600    0.008    0.000    4.119    0.007 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/function.py:501(apply)
#  1488/600    0.033    0.000    4.108    0.007 {built-in method apply}
#       100    0.001    0.000    3.932    0.039 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:145(equilibrium)
#       100    0.000    0.000    3.901    0.039 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:351(_rootfinder)
#       100    0.002    0.000    3.892    0.039 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:482(forward)
#       100    0.003    0.000    3.887    0.039 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:229(broyden1)
#       100    0.071    0.001    3.885    0.039 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:40(_nonlin_solver)

# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    print("CUDA is available. Devices:")
    # Print the number of available CUDA devices
    for i in range(torch.cuda.device_count()):
        print(f"Device {i}: {torch.cuda.get_device_name(i)}")
else:
    print("CUDA is not available.")
# Out:
# CUDA is available. Devices:
# Device 0: TITAN RTX
