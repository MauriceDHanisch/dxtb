# %%
# %reload_ext autoreload
# %autoreload 2

from log_funcs import *

res_grid = parse_grid_log(f"../logs/alkane_chain_E_grid_batch_CUPY2.txt", keyword="Total")

print([res['n'] for res in res_grid[1:-1]])
# plot_grid_times(res_grid[1:-1][0:], dpi=500)
plot_time_vs_n_atoms_at_batch_size(res_grid[1:-13][0:], batch_size=64, dpi=300, highlight_intervals=[[15, 35], [50, 70]])
# Out:
# [8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50, 53, 56, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 113]
