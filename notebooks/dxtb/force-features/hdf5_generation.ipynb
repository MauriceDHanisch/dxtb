# %%
# %reload_ext autoreload
# %autoreload 2

import h5py
from tqdm import tqdm

from qcm_ml.features.xtb import generate_xtb_matrices_fpsh, get_2body_grads

src_path = "/home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/data/rmd17/rmd17_aspirin.hdf5"
tgt_path = "/home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/data/rmd17/rmd17_aspirin_DXTB.hdf5"

def generate_hdf5(max_molecules=int(1e6)):
    idx = 0
    with h5py.File(src_path, 'r') as src_file:
        with h5py.File(tgt_path, 'w') as tgt_file:
            for mode in src_file:  # e.g., "train", "test"
                for mol in src_file[mode]:  # e.g., "aspirin"
                    for geo_idx in tqdm(src_file[f"{mode}/{mol}"], desc=f"{mode}/{mol} geometries"):  # Iterate over geometry indices (e.g., "10097", "10139")
                        idx += 1
                        if idx > max_molecules:
                            break
                        src_geo_group = src_file[f"{mode}/{mol}/{geo_idx}"]
                        tgt_geo_group = tgt_file.create_group(f"{mode}/{mol}/{geo_idx}")

                        for key, item in src_geo_group.items():
                            # Skip 2body and 2body_grad groups
                            if key in ["2body", "2body_grad"]:
                                continue
                            else: 
                                if item.shape == ():
                                    tgt_geo_group.create_dataset(key, data=item[()])
                                else:
                                    tgt_geo_group.create_dataset(key, data=item[:])

                        # Calculation of 2body features
                        numbers = src_geo_group["atomic_numbers"][:] 
                        positions = src_geo_group["geometry_bohr"][:]

                        T = generate_xtb_matrices_fpsh(
                            calculator="dxtb",
                            element_numbers=numbers,
                            coordinates=positions,
                            spin=0,
                            spin_pol=False,
                            get_energy=True,
                            get_forces=True,
                            )
                        
                        # grads = get_2body_grads(element_numbers=numbers, coordinates=positions)
                        
                        for M in ["F", "P", "S", "H"]:
                            tgt_geo_group.create_dataset(f"2body/{M}", data=T[M])
                            tgt_geo_group.create_dataset(f"2body_grad/{M}", data=T[f"grad_{M}"])

                        tgt_geo_group.create_dataset("energy_delta_dxtb_Ha")

                        
                        
                            
generate_hdf5(max_molecules=1)
# Out:
# train/aspirin geometries:   0%|          | 1/1000 [01:07<18:40:11, 67.28s/it]
# val/aspirin geometries:   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# # Profiler

# %%
import cProfile
import pstats
import io

pr = cProfile.Profile()
pr.enable()

generate_hdf5(10)

pr.disable()
s = io.StringIO()
sortby = 'cumtime'  # Sort by cumulative time
ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
# train/aspirin geometries:   0%|          | 0/1000 [00:00<?, ?it/s]
# train/aspirin geometries:   1%|          | 11/1000 [06:43<10:04:43, 36.69s/it]
# val/aspirin geometries:   0%|          | 0/1000 [00:00<?, ?it/s]
#          106182816 function calls (105566975 primitive calls) in 403.581 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  403.584  201.792 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3514(run_code)
#         2    0.000    0.000  403.584  201.792 {built-in method builtins.exec}
#         1    0.000    0.000  403.584  403.584 /tmp/ipykernel_22794/3008304535.py:8(<module>)
#         1    0.014    0.014  403.584  403.584 /tmp/ipykernel_22794/2221312473.py:12(generate_hdf5)
#        11    0.004    0.000  403.387   36.672 /home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:102(generate_xtb_matrices_fpsh)
#        11    0.127    0.012  403.354   36.669 /home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:212(generate_xtb_matrices_dxtb)
#        44    2.703    0.061  401.496    9.125 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/functional.py:499(jacobian)
#    203456    1.407    0.000  394.174    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/functional.py:147(_autograd_grad)
# 203606/203467    1.556    0.000  393.126    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/__init__.py:204(grad)
# 203606/203467  194.984    0.001  388.026    0.002 {method 'run_backward' of 'torch._C._EngineBase' objects}
# 152775/152636    2.115    0.000  193.174    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/function.py:264(apply)
#    152603    7.987    0.000  190.645    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:55(backward)
#    152603    2.355    0.000   97.788    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/utils.py:40(get_integrals)
# 152908/152790    0.793    0.000   89.649    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/function.py:501(apply)
#    152603    0.145    0.000   89.239    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:79(int_fcn)
#    152724    0.309    0.000   89.141    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:285(_int2c)
# 152908/152790    2.915    0.000   86.757    0.001 {built-in method apply}
#    152724    0.771    0.000   82.620    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:242(forward)
#    152724    0.181    0.000   64.554    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:80(calc)
#    152724   56.021    0.000   64.373    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:102(_int2c)
#    306649    0.267    0.000   61.316    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/math/einsum.py:58(einsum)
#    306638    0.578    0.000   61.043    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/math/einsum.py:50(einsum_greedy)
#    306649    0.857    0.000   60.470    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/math/einsum.py:43(_torch_einsum)
#    306649    2.877    0.000   59.614    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:378(contract)
#    306649    1.569    0.000   29.245    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:530(_core_contract)
#    306608    0.509    0.000   26.916    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/sharing.py:148(cached_einsum)
#    306704    8.252    0.000   26.752    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:93(contract_path)
#    306608    0.972    0.000   26.037    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:333(_einsum)
#    306608    0.715    0.000   23.253    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/backends/torch.py:37(einsum)
# 613282/306674    2.650    0.000   18.023    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/functional.py:192(einsum)
#    152724    2.545    0.000   16.425    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:50(__init__)
#    306674   14.372    0.000   14.372    0.000 {built-in method torch.einsum}
#    152603    0.434    0.000   11.604    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:72(<listcomp>)
#    305206    1.481    0.000   11.171    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:171(get_intgl_deriv_namemgr)
#    152724    3.602    0.000    9.291    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:148(_get_intgl_optimizer)
#   1069068    3.622    0.000    7.929    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/utils.py:44(np2ctypes)
#    305327    0.906    0.000    7.385    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:80(__init__)
#    305327    1.842    0.000    6.436    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:350(split_name)
#    662749    5.960    0.000    5.960    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#    306608    1.111    0.000    4.464    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:87(convert_to_valid_einsum_chars)
#    307097    0.515    0.000    3.829    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:141(find_output_shape)
#    306704    1.713    0.000    3.564    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:246(parse_einsum_input)
#   1221792    1.081    0.000    3.485    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/numpy/core/_internal.py:266(data_as)
#    920208    1.465    0.000    3.313    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:154(<genexpr>)
#    305206    3.233    0.000    3.233    0.000 {built-in method torch.scatter_add}
#    305327    0.497    0.000    3.023    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:399(<listcomp>)
#    307097    1.719    0.000    2.979    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/helpers.py:82(find_contraction)
#   1533440    1.183    0.000    2.721    0.000 {method 'join' of 'str' objects}
#   1374516    2.720    0.000    2.720    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/ctypes/__init__.py:517(cast)
#    610654    0.589    0.000    2.527    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/re.py:233(findall)
#   2445498    1.540    0.000    2.366    0.000 {built-in method builtins.sum}
#    458796    2.323    0.000    2.323    0.000 {method 'transpose' of 'torch._C._TensorBase' objects}
#        55    0.002    0.000    2.216    0.040 /home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:232(compute_matrices)
#    203606    0.718    0.000    2.118    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/__init__.py:50(_make_grads)
#    152724    0.360    0.000    1.995    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/convert/numpy.py:60(numpy_to_tensor)
#    915981    1.524    0.000    1.961    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/re.py:289(_compile)
#    152603    1.413    0.000    1.866    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:304(get_comp_permute_path)
#    356817    1.858    0.000    1.858    0.000 {built-in method torch.zeros_like}
#    152908    0.515    0.000    1.813    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/_functorch/utils.py:18(unwrap_dead_wrappers)
#    307097    1.307    0.000    1.760    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/blas.py:12(can_blas)
#    152603    0.355    0.000    1.691    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:74(<listcomp>)
#    305206    0.853    0.000    1.599    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:403(join_name)
#   3980494    1.083    0.000    1.533    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:99(<genexpr>)
#    306608    0.243    0.000    1.514    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:35(has_valid_einsum_chars_only)
# 1384590/1079142    1.205    0.000    1.430    0.000 {built-in method builtins.getattr}
#   1221792    1.415    0.000    1.415    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/numpy/core/_internal.py:249(__init__)
#    614681    0.588    0.000    1.391    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/helpers.py:137(flop_count)
#   1233119    0.876    0.000    1.391    0.000 {built-in method builtins.max}
#    305206    0.812    0.000    1.336    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:196(get_intgl_deriv_newaxispos)
#   5433818    1.327    0.000    1.327    0.000 {built-in method builtins.isinstance}
#   9934272    1.291    0.000    1.303    0.000 {built-in method builtins.len}
#   1069711    0.640    0.000    1.297    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/_functorch/utils.py:20(<genexpr>)
#    306366    1.291    0.000    1.291    0.000 {method 'expand' of 'torch._C._TensorBase' objects}
#    308709    0.695    0.000    1.277    0.000 {built-in method builtins.all}
#    204011    1.185    0.000    1.185    0.000 {built-in method torch.ones_like}
#   1844459    1.178    0.000    1.178    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/helpers.py:53(compute_size_by_dict)
#    152724    0.747    0.000    1.120    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:227(get_intgl_components_shape)
#    305206    1.117    0.000    1.117    0.000 {built-in method torch.movedim}
#        44    0.009    0.000    1.071    0.024 /home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:251(<lambda>)
#   4283618    1.051    0.000    1.051    0.000 {method 'append' of 'list' objects}
#    306704    0.521    0.000    1.043    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:244(<listcomp>)
#    152603    1.039    0.000    1.039    0.000 {method 'permute' of 'torch._C._TensorBase' objects}
#    152724    0.227    0.000    1.022    0.000 <__array_function__ internals>:177(swapaxes)
#    152724    0.989    0.000    0.989    0.000 {built-in method torch.from_numpy}
#    457831    0.667    0.000    0.975    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/copy.py:66(copy)
#    152603    0.137    0.000    0.947    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/utils.py:112(_transpose)
#    306704    0.328    0.000    0.911    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:277(<listcomp>)
#       110    0.001    0.000    0.910    0.008 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/wrappers.py:137(overlap)
#       110    0.004    0.000    0.908    0.008 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/wrappers.py:205(_integral)
#    305327    0.216    0.000    0.893    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/re.py:250(compile)
#       176    0.001    0.000    0.882    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/base.py:691(get_property)
#       176    0.000    0.000    0.879    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/base.py:51(calculate)
#       176    0.002    0.000    0.879    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/autograd.py:1001(calculate)
#       176    0.003    0.000    0.877    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/decorators.py:228(wrapper)
#        55    0.000    0.000    0.877    0.016 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/abc.py:415(get_density)
#        11    0.000    0.000    0.872    0.079 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/energy.py:361(energy)
#        11    0.002    0.000    0.871    0.079 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/energy.py:78(singlepoint)
#   2763292    0.839    0.000    0.839    0.000 {method 'count' of 'str' objects}
#    152724    0.630    0.000    0.839    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:141(__del__)
#        55    0.002    0.000    0.802    0.015 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/wrappers.py:81(hcore)
#   1023263    0.791    0.000    0.792    0.000 {built-in method builtins.hasattr}
#    610896    0.428    0.000    0.749    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/lazyloader/so.py:58(__getattr__)
#    613111    0.466    0.000    0.744    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:155(<listcomp>)
#    152724    0.175    0.000    0.740    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    921195    0.735    0.000    0.735    0.000 {built-in method builtins.sorted}
#    306608    0.461    0.000    0.729    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:98(<dictcomp>)
#    407212    0.272    0.000    0.714    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/overrides.py:1750(is_tensor_like)
#    152724    0.707    0.000    0.707    0.000 {built-in method numpy.empty}
#        11    0.000    0.000    0.657    0.060 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/iterator.py:51(solve)
#    611226    0.656    0.000    0.656    0.000 {method 'findall' of 're.Pattern' objects}
#       121    0.005    0.000    0.648    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/driver/libcint/driver.py:43(setup)
#    152603    0.422    0.000    0.630    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:241(get_transpose_path_to)
#        11    0.000    0.000    0.618    0.056 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:413(__call__)
#   4140577    0.608    0.000    0.608    0.000 {method 'get' of 'dict' objects}
#   280/140    0.001    0.000    0.591    0.004 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/pure_function.py:55(__call__)
#       140    0.001    0.000    0.591    0.004 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:217(new_fcn)
#   3987474    0.591    0.000    0.591    0.000 {method 'pop' of 'dict' objects}
#       140    0.001    0.000    0.589    0.004 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:719(iterate_potential)
#   1538572    0.588    0.000    0.588    0.000 {method 'replace' of 'str' objects}
#        11    0.000    0.000    0.585    0.053 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/implicit/default.py:53(scf)
#    613801    0.234    0.000    0.583    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:158(possibly_convert_to_numpy)
#   3673886    0.579    0.000    0.579    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:21(is_valid_einsum_char)
#    921291    0.397    0.000    0.569    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/helpers.py:126(<genexpr>)
#    152724    0.132    0.000    0.565    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/numpy/core/fromnumeric.py:550(swapaxes)
#    305206    0.399    0.000    0.554    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:428(<listcomp>)
#        11    0.000    0.000    0.545    0.050 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:145(equilibrium)
#        11    0.000    0.000    0.542    0.049 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:351(_rootfinder)
#        11    0.000    0.000    0.541    0.049 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:482(forward)
#        11    0.000    0.000    0.541    0.049 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:229(broyden1)
#        11    0.009    0.001    0.540    0.049 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:40(_nonlin_solver)
#       151    0.001    0.000    0.518    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:796(potential_to_charges)
#   1532830    0.511    0.000    0.511    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:155(<genexpr>)
#       766    0.004    0.000    0.511    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/timing/decorator.py:54(wrapper)
#   2456483    0.509    0.000    0.509    0.000 {method 'pop' of 'list' objects}
#       118    0.001    0.000    0.495    0.004 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/rootsolver.py:128(<lambda>)
#   1229028    0.494    0.000    0.494    0.000 {method 'split' of 'str' objects}
#    458172    0.298    0.000    0.492    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:75(<genexpr>)
#    916344    0.485    0.000    0.485    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/utils.py:61(int2ctypes)
#    152603    0.204    0.000    0.470    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/utils.py:119(_swap_list)
#    152724    0.390    0.000    0.462    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:189(_get_uniqueness)
#    458466    0.451    0.000    0.451    0.000 {built-in method torch._C._functorch.unwrap_if_dead}
#       151    0.001    0.000    0.443    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:813(potential_to_density)
#    152724    0.165    0.000    0.433    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#       151    0.011    0.000    0.428    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:928(hamiltonian_to_density)
#    152724    0.296    0.000    0.410    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:264(setup_context)
#        11    0.001    0.000    0.398    0.036 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:375(backward)
#    307097    0.254    0.000    0.384    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:289(<listcomp>)
#    458172    0.248    0.000    0.377    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:77(<genexpr>)
# 610698/610654    0.373    0.000    0.374    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/utils.py:85(new_fcn)
#    154503    0.372    0.000    0.372    0.000 {method 'type' of 'torch._C._TensorBase' objects}
#    306932    0.269    0.000    0.370    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/sharing.py:23(currently_sharing)
#    920505    0.295    0.000    0.362    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:253(<genexpr>)
#    614194    0.359    0.000    0.359    0.000 {method 'union' of 'set' objects}
#    306932    0.244    0.000    0.358    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:552(<listcomp>)
#    407212    0.339    0.000    0.339    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/typing.py:271(inner)
#       176    0.001    0.000    0.328    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:283(from_numbers)
#    152724    0.213    0.000    0.328    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:127(get_intgl_name)
#    306998    0.206    0.000    0.300    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/_VF.py:26(__getattr__)
#       176    0.028    0.000    0.294    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:320(from_numbers_angular)
#    820168    0.293    0.000    0.293    0.000 {built-in method torch._C._has_torch_function}
#       121    0.065    0.001    0.293    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/wrapper.py:62(__init__)
#       121    0.096    0.001    0.290    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/bas.py:407(create_libcint)
#    152908    0.288    0.000    0.288    0.000 {built-in method torch._C._are_functorch_transforms_active}
#    157726    0.287    0.000    0.287    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#    307097    0.191    0.000    0.285    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:290(<listcomp>)
#   1227848    0.279    0.000    0.279    0.000 {method 'find' of 'str' objects}
#    306704    0.274    0.000    0.274    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:214(<listcomp>)
#   1226789    0.269    0.000    0.269    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/parser.py:49(get_symbol)
#        11    0.000    0.000    0.255    0.023 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/linalg/solve.py:49(solve)
#    152724    0.163    0.000    0.254    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/intor.py:62(<listcomp>)
#        11    0.000    0.000    0.252    0.023 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/linalg/solve.py:180(solve_torchfcn)
#        11    0.001    0.000    0.251    0.023 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/linalg/solve.py:358(forward)
#    306704    0.249    0.000    0.249    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:218(<listcomp>)
#        11    0.007    0.001    0.244    0.022 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/solve.py:243(bicgstab)
#    306649    0.226    0.000    0.226    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:475(<dictcomp>)
#    203606    0.136    0.000    0.211    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/__init__.py:98(_tensor_or_tensors_to_tuple)
#       151    0.001    0.000    0.208    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/implicit/base.py:70(diagonalize)
#    305206    0.208    0.000    0.208    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:290(_swap)
#    152724    0.206    0.000    0.206    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#    610533    0.205    0.000    0.205    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:448(get_nbasis)
#        66    0.016    0.000    0.203    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/xtb/gfn1.py:264(build)
#    306932    0.195    0.000    0.195    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/backends/dispatch.py:60(get_func)
#     21109    0.030    0.000    0.177    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/_tensor.py:920(__iter__)
#       117    0.000    0.000    0.174    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/solve.py:674(<lambda>)
#       117    0.002    0.000    0.173    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/linop.py:289(mm)
#    152724    0.172    0.000    0.172    0.000 {built-in method _functools.reduce}
#       117    0.001    0.000    0.168    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/linop.py:664(_mv)
#       117    0.003    0.000    0.168    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/grad/jachess.py:246(_rmv)
#    305448    0.163    0.000    0.163    0.000 {built-in method _ctypes.byref}
#       726    0.115    0.000    0.160    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/slater.py:69(slater_to_gauss)
#       528    0.111    0.000    0.153    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:61(_fill)
#    457809    0.152    0.000    0.152    0.000 {method 'copy' of 'list' objects}
#    152724    0.150    0.000    0.150    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:105(order)
#       151    0.000    0.000    0.146    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/linalg/symeig.py:47(lsymeig)
#       151    0.004    0.000    0.145    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/linalg/symeig.py:85(symeig)
#       151    0.003    0.000    0.140    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/symeig.py:39(exacteig)
#    152724    0.139    0.000    0.139    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:232(<listcomp>)
#    305206    0.138    0.000    0.138    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:329(<listcomp>)
#       209    0.001    0.000    0.136    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/storch/distance.py:121(cdist)
#       209    0.016    0.000    0.135    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/storch/distance.py:34(euclidean_dist_quadratic_expansion)
#    306704    0.133    0.000    0.133    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:74(_choose_memory_arg)
#    305613    0.129    0.000    0.129    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/wrapper.py:278(shell_idxs)
#     21109    0.126    0.000    0.126    0.000 {method 'unbind' of 'torch._C._TensorBase' objects}
#    206008    0.124    0.000    0.124    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#       162    0.001    0.000    0.122    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:768(charges_to_potential)
#       162    0.003    0.000    0.120    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/interactions/list.py:229(get_potential)
#    152908    0.115    0.000    0.115    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/function.py:18(save_for_backward)
#    152724    0.114    0.000    0.114    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:89(fullname)
#    614584    0.114    0.000    0.114    0.000 {method 'items' of 'dict' objects}
#       176    0.005    0.000    0.112    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/group.py:67(create_dataset)
#       324    0.006    0.000    0.112    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/interactions/base.py:133(get_potential)
#    152724    0.106    0.000    0.106    0.000 {built-in method _ctypes.POINTER}
#        66    0.004    0.000    0.106    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/xtb/gfn1.py:50(__init__)
#       264    0.103    0.000    0.103    0.000 {built-in method torch.stack}
#    152724    0.102    0.000    0.102    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/wrapper.py:262(atm_bas_env)
#    306649    0.102    0.000    0.102    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/backends/dispatch.py:76(has_einsum)
#    306951    0.101    0.000    0.101    0.000 {built-in method _thread.get_ident}
#        88    0.000    0.000    0.100    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/autograd/functional.py:705(<genexpr>)
#       151    0.031    0.000    0.100    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/wavefunction/filling.py:264(get_fermi_occupation)
#    306932    0.097    0.000    0.097    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/backends/torch.py:18(_get_torch_and_device)
#    306510    0.091    0.000    0.091    0.000 {built-in method builtins.id}
#       176    0.069    0.000    0.090    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/dataset.py:35(make_new_dset)
#    305206    0.087    0.000    0.087    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:218(<genexpr>)
#       151    0.000    0.000    0.085    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/utils.py:28(get_density)
#    306649    0.083    0.000    0.083    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:489(<listcomp>)
#       176    0.006    0.000    0.082    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:74(_expand)
#    306649    0.079    0.000    0.079    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:514(parse_backend)
#        77    0.005    0.000    0.077    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/ncoord/d3.py:37(cn_d3)
#       151    0.001    0.000    0.077    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/symeig.py:161(_degen_symeig)
#      2097    0.006    0.000    0.073    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/utils/scattergather.py:285(wrap_gather)
#       151    0.003    0.000    0.072    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:831(density_to_charges)
#        11    0.000    0.000    0.071    0.006 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/container.py:169(build_overlap)
#       151    0.001    0.000    0.070    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/symeig.py:150(forward)
#       151    0.000    0.000    0.069    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/utils/math.py:34(eigh)
#       151    0.069    0.000    0.069    0.000 {built-in method torch._C._linalg.linalg_eigh}
#    407216    0.069    0.000    0.069    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/typing.py:1375(cast)
#        11    0.000    0.000    0.066    0.006 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/grad/jachess.py:39(jac)
#        11    0.000    0.000    0.066    0.006 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/grad/jachess.py:71(<listcomp>)
#        11    0.000    0.000    0.066    0.006 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/grad/jachess.py:140(__init__)
#       176    0.022    0.000    0.064    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:80(<listcomp>)
#    152724    0.063    0.000    0.063    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:97(int_type)
#       121    0.002    0.000    0.063    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/driver/libcint/overlap.py:51(build)
#        11    0.000    0.000    0.059    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/driver/manager.py:111(setup_driver)
#       187    0.022    0.000    0.057    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/param/utils.py:189(get_elem_valence)
#       736    0.010    0.000    0.057    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/utils/scattergather.py:416(wrap_scatter_reduce)
#    153054    0.057    0.000    0.057    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/wrapper.py:284(full_shell_to_aoloc)
#       121    0.003    0.000    0.056    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/bas.py:97(__init__)
#        11    0.001    0.000    0.056    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/types/base.py:439(__init__)
#    152724    0.055    0.000    0.055    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/numpy/core/fromnumeric.py:546(_swapaxes_dispatcher)
#        66    0.046    0.001    0.054    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/xtb/gfn1.py:178(_get_hscale)
#       121    0.001    0.000    0.054    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/base.py:320(normalize)
#       223    0.001    0.000    0.054    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/solve.py:533(_dot)
#       121    0.000    0.000    0.052    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:397(overlap)
#       121    0.001    0.000    0.052    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/integrals/int_2c1e.py:361(int1e)
#        11    0.000    0.000    0.051    0.005 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/classicals/list.py:93(get_energy)
#      5147    0.049    0.000    0.049    0.000 {built-in method torch.tensor}
#    152724    0.048    0.000    0.048    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/wrapper.py:247(spherical)
#       379    0.043    0.000    0.043    0.000 {built-in method torch.allclose}
#       206    0.043    0.000    0.043    0.000 {built-in method torch.inverse}
#       151    0.017    0.000    0.042    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/wavefunction/filling.py:196(get_fermi_energy)
#       302    0.002    0.000    0.042    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/linop.py:91(m)
#       150    0.021    0.000    0.042    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/symeig.py:87(backward)
#      1679    0.020    0.000    0.041    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/utils/scattergather.py:248(wrapper)
#        11    0.000    0.000    0.040    0.004 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/base.py:463(converged_to_charges)
#        11    0.000    0.000    0.039    0.004 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/classicals/dispersion/d3.py:148(get_energy)
#       151    0.006    0.000    0.039    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/implicit/base.py:51(get_overlap)
#    152724    0.039    0.000    0.039    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/namemanager.py:234(<listcomp>)
#       736    0.009    0.000    0.037    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/utils/scattergather.py:336(scatter_reduce)
#      3580    0.034    0.000    0.034    0.000 {built-in method torch.where}
#       173    0.000    0.000    0.034    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/interactions/coulomb/secondorder.py:389(get_shell_potential)
#        11    0.000    0.000    0.033    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/container.py:127(build_hcore)
#        11    0.000    0.000    0.033    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/guess.py:35(get_guess)
#       176    0.001    0.000    0.032    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/param/utils.py:161(get_elem_angular)
#      9419    0.032    0.000    0.032    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#       176    0.024    0.000    0.032    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/param/utils.py:183(<dictcomp>)
#      3280    0.004    0.000    0.032    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/_tensor.py:34(wrapped)
#       775    0.001    0.000    0.031    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:572(spread_atom_to_shell)
#        11    0.000    0.000    0.029    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/scf/guess.py:92(get_eeq_guess)
#       379    0.001    0.000    0.029    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:503(reduce_shell_to_atom)
#        11    0.000    0.000    0.029    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_multicharge/model/eeq.py:292(get_charges)
#        11    0.000    0.000    0.029    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_multicharge/model/eeq.py:239(get_eeq)
#       357    0.001    0.000    0.029    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:471(reduce_orbital_to_shell)
#       272    0.001    0.000    0.028    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/paths.py:618(greedy)
#        11    0.000    0.000    0.028    0.003 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/classicals/list.py:61(get_cache)
#        88    0.028    0.000    0.028    0.000 /home/beom/orbnet_mhd/qcm_ml_b/qcm_ml/features/xtb.py:63(apply_perm_map)
#       418    0.005    0.000    0.026    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/utils/scattergather.py:62(wrapper)
#       121    0.006    0.000    0.025    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/ortho.py:74(orthogonalize)
#       638    0.008    0.000    0.024    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/param/utils.py:88(get_elem_param)
#      5082    0.024    0.000    0.024    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/wrapper.py:158(<listcomp>)
#       706    0.001    0.000    0.023    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/indexhelper.py:599(spread_shell_to_orbital)
#      1053    0.023    0.000    0.023    0.000 {built-in method torch.matmul}
#      5082    0.023    0.000    0.023    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_libcint/interface/wrapper.py:159(<listcomp>)
#        11    0.001    0.000    0.022    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/classicals/dispersion/d3.py:85(get_cache)
#      3378    0.022    0.000    0.022    0.000 {built-in method torch.gather}
#        66    0.001    0.000    0.022    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/xtb/gfn1.py:140(_get_elem_valence)
#      2765    0.022    0.000    0.022    0.000 {built-in method torch.all}
#       234    0.002    0.000    0.021    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/grad/jachess.py:290(connect_graph)
#      2916    0.021    0.000    0.021    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#        11    0.000    0.000    0.021    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/factory.py:47(new_hcore)
#     13211    0.021    0.000    0.021    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#        11    0.000    0.000    0.021    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/factory.py:76(new_hcore_gfn1)
#      4235    0.020    0.000    0.020    0.000 {built-in method torch.arange}
#        22    0.000    0.000    0.020    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_dftd3/reference.py:202(__init__)
#       213    0.010    0.000    0.019    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/group.py:348(__getitem__)
#       324    0.001    0.000    0.019    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/sharing.py:128(cached_tensordot)
#       418    0.004    0.000    0.019    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/utils/scattergather.py:86(twice)
#       107    0.001    0.000    0.018    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/_jacobian.py:103(update)
#        11    0.000    0.000    0.018    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_dftd3/reference.py:162(_load_c6)
#       324    0.001    0.000    0.018    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/contract.py:369(_tensordot)
#       176    0.000    0.000    0.018    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/base.py:102(array_for_new_object)
#       151    0.018    0.000    0.018    0.000 {built-in method torch._C._linalg.linalg_cholesky}
#       327    0.013    0.000    0.017    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/paths.py:63(ssa_to_linear)
#       324    0.001    0.000    0.017    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/opt_einsum/backends/torch.py:48(tensordot)
#       242    0.007    0.000    0.017    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/basis/ortho.py:36(gaussian_integral)
#        11    0.003    0.000    0.017    0.002 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_multicharge/model/eeq.py:107(solve)
#       112    0.001    0.000    0.016    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/files.py:376(__init__)
#       176    0.016    0.000    0.016    0.000 {built-in method numpy.asarray}
#       324    0.002    0.000    0.016    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/functional.py:1014(tensordot)
#        11    0.000    0.000    0.016    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/interactions/list.py:197(get_cache)
#        11    0.000    0.000    0.016    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:671(load)
#        11    0.000    0.000    0.016    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/interactions/list.py:220(<dictcomp>)
#       121    0.000    0.000    0.016    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/base.py:435(__iter__)
#       275    0.000    0.000    0.015    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_mctc/batch/mask/pairs.py:34(real_pairs)
#       234    0.010    0.000    0.015    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/grad/jachess.py:293(<listcomp>)
#        11    0.000    0.000    0.015    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/interactions/coulomb/secondorder.py:204(get_cache)
#        11    0.001    0.000    0.015    0.001 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_dftd3/model/c6.py:285(backward)
#       330    0.002    0.000    0.015    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/xtb/gfn1.py:119(_get_elem_param)
# ...
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/storage.py:1020(_get_dtype_from_pickle_storage_type)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/optimize/root/_jacobian.py:61(__init__)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:347(<listcomp>)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:240(__init__)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/unique.py:71(<listcomp>)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/inspect.py:81(ismethod)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/_weakrefset.py:111(remove)
#        19    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/threading.py:271(_is_owned)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/inspect.py:159(isfunction)
#        19    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/grad/jachess.py:188(<listcomp>)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/psutil/_common.py:862(get_procfs_path)
#        22    0.000    0.000    0.000    0.000 {method 'tell' of '_io.BufferedReader' objects}
#        69    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/misc.py:115(nnontensors)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/list.py:145(<setcomp>)
#        48    0.000    0.000    0.000    0.000 {built-in method time.time}
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/base.py:304(requires_grad)
#         6    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        19    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/threading.py:265(_release_save)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/editable_module.py:149(<listcomp>)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/pure_function.py:241(make_sibling)
#        33    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/calculators/config/main.py:334(batch_mode)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/interactions/container.py:317(mono)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:361(_check_dill_version)
#        74    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        33    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/linop.py:536(dtype)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_impls/linalg/solve.py:658(_setup_linear_problem)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/editable_module.py:153(<listcomp>)
#        33    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/base.py:506(product)
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/_weakrefset.py:53(_commit_removals)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:1062(_maybe_decode_ascii)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:1154(UnpicklerWrapper)
#        21    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#        38    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/components/list.py:241(<listcomp>)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/bcast.py:32(<listcomp>)
#        15    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:108(__init__)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/pure_function.py:66(objparams)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/_weakrefset.py:86(add)
#        15    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:167(colour)
#        11    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        44    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_dftd3/reference.py:241(device)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/_collections_abc.py:802(__init__)
#        19    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:424(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/compat.py:11(filename_encode)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:266(_supports_unicode)
#        11    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#        33    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/base.py:171(_lcpl)
#        15    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:112(__format__)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/functools.py:392(__get__)
#        44    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tad_dftd3/reference.py:253(dtype)
#        33    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_core/linop.py:540(device)
#        21    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#        22    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/base.py:116(is_latest)
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/_weakrefset.py:21(__enter__)
#        26    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        33    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/dataset.py:770(<genexpr>)
#        11    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/traitlets/traitlets.py:676(__get__)
#         6    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/misc.py:109(get_tensor_params)
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/unique.py:53(get_unique_objs)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:1074(_get_restore_location)
#        19    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/misc.py:77(dummy_context_manager)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:125(__eq__)
#        22    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method fromtimestamp}
#        19    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        22    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:243(__enter__)
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:187(disable_on_exception)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:156(__init__)
#        11    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:222(__eq__)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/container.py:256(dipole)
#         6    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:152(wrapper_setattr)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:157(_cpu_deserialize)
#        11    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        19    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#        21    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/os.py:804(fsencode)
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:1157(__hash__)
#        15    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:163(colour)
#        11    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_22794/3008304535.py:10(<module>)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/integral/container.py:327(quadrupole)
#        11    0.000    0.000    0.000    0.000 {method 'data_ptr' of 'torch._C.StorageBase' objects}
#         2    0.000    0.000    0.000    0.000 {method 'set_alignment' of 'h5py.h5p.PropFAID' objects}
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/timing/timer.py:224(cuda_sync)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/_monitor.py:94(report)
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/IPython/core/compilerop.py:180(extra_flags)
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:1153(_comparable)
#        19    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/assertfuncs.py:52(assert_type)
#         6    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:226(__init__)
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:139(__getattr__)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/traitlets/traitlets.py:629(get)
#        19    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/_weakrefset.py:17(__init__)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/optimize/rootfinder.py:532(_get_rootfinder_default_method)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/dxtb/_src/exlibs/xitorch/_utils/bcast.py:42(<listcomp>)
#        11    0.000    0.000    0.000    0.000 {method 'clear' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:252(_is_utf)
#        11    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/torch/serialization.py:246(__exit__)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:1147(__del__)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3466(compare)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/ipykernel/iostream.py:348(fileno)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:760(get_lock)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/utils.py:282(_screen_shape_wrapper)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/IPython/core/interactiveshell.py:1255(user_global_ns)
#         4    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         2    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/files.py:186(make_fcpl)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/tqdm/std.py:1301(<lambda>)
#         2    0.000    0.000    0.000    0.000 /home/beom/anaconda3/envs/orbnet_tblite/lib/python3.9/site-packages/h5py/_hl/files.py:592(__enter__)
